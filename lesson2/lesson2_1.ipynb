# %%
print("hello! python")
print(9+3)
print(9/3)
print(9//3)
print(4*7)
# Out:
# hello! python
# 12
# 3.0
# 3
# 28

# %%
# python的基本資料型別
# int
5
15

# float
5.0

# str
"5"
'5'

# bool
True
False

5 + 5

5 + 5.0

5 + int('5')
# Out:
# 10
